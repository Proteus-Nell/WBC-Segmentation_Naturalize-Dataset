# %%
# ============================================================
# Cell 1: Imports & Setup
# ============================================================

# Python Standard Libraries
import os

# External Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2


# Pytorch Libraries
import torch
import torch.nn as nn

# %%
ROOT_DIR = r"C:\Users\User1\Documents\GitHub\IIP-G8\Misc Files\Naturalize Dataset\Naturalize Dataset"
FILE_DIR = os.getcwd()

TEST_IMG = os.path.join(ROOT_DIR, r"BA\BA 2k-PBC Train (24).jpg")

# PyPlot!
img = plt.imread(TEST_IMG)
plt.imshow(img)
plt.axis('off')
plt.show()

# CV2
img = cv2.imread(TEST_IMG)
img_RGB = cv2.cvtColor(TEST_IMG, cv2.COLOR_BGR2RGB)
img_HSV = cv2.cvtColor(TEST_IMG, cv2.COLOR_BGR2HSV)


# Root Checks
print(TEST_IMG)
print(ROOT_DIR)
print(FILE_DIR)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[29], line 14
#      12 # CV2
#      13 img = cv2.imread(TEST_IMG)
# ---> 14 img_RGB = cv2.cvtColor(TEST_IMG, cv2.COLOR_BGR2RGB)
#      15 img_HSV = cv2.cvtColor(TEST_IMG, cv2.COLOR_BGR2HSV)
#      18 # Root Checks
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
